# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoVillalobosB/Machine_Learning_2022/blob/Main/PROYECTO_7_16_05_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('https://raw.githubusercontent.com/labeconometria/proyectos/main/economicas.csv')

# %%
data
# Out:
#      ESTU_CONSECUTIVO  RESULT_CODIGOPRUEBA RESULT_NOMBREPRUEBA  \
# 0      EK202120243329                 2001  ANÁLISIS ECONÓMICO
# 1      EK202120227314                 2001  ANÁLISIS ECONÓMICO
# 2      EK202120088295                 2001  ANÁLISIS ECONÓMICO
# 3      EK202120120119                 2001  ANÁLISIS ECONÓMICO
# 4      EK202120248108                 2001  ANÁLISIS ECONÓMICO
# ...               ...                  ...                 ...
# 3850   EK202120232172                 2001  ANÁLISIS ECONÓMICO
# 3851   EK202120320571                 2001  ANÁLISIS ECONÓMICO
# 3852   EK202120313923                 2001  ANÁLISIS ECONÓMICO
# 3853   EK202120281981                 2001  ANÁLISIS ECONÓMICO
# 3854   EK202120224998                 2001  ANÁLISIS ECONÓMICO
#
#       RESULT_PUNTAJE  RESULT_DESEMPENO ESTU_AGREGADO ESTU_TIPODOCUMENTO  \
# 0                128                 2             S                 CC
# ...

# %%
data.describe()#descripcion
# Out:
#        RESULT_CODIGOPRUEBA  RESULT_PUNTAJE  RESULT_DESEMPENO  PERIODO  \
# count               3855.0     3855.000000       3855.000000   3855.0
# mean                2001.0      123.739818          1.622049  20212.0
# std                    0.0       36.175271          0.823615      0.0
# min                 2001.0        0.000000          1.000000  20212.0
# 25%                 2001.0      102.000000          1.000000  20212.0
# 50%                 2001.0      119.000000          1.000000  20212.0
# 75%                 2001.0      144.000000          2.000000  20212.0
# max                 2001.0      300.000000          4.000000  20212.0
#
#        ESTU_COD_RESIDE_DEPTO  ESTU_COD_RESIDE_MCPIO  \
# count            3855.000000            3855.000000
# mean               55.073152           29283.845396
# std              1610.310349           25136.372255
# min                 5.000000            5001.000000
# 25%                11.000000           11001.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3855 entries, 0 to 3854
# Data columns (total 97 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ESTU_CONSECUTIVO                3855 non-null   object
#  1   RESULT_CODIGOPRUEBA             3855 non-null   int64
#  2   RESULT_NOMBREPRUEBA             3855 non-null   object
#  3   RESULT_PUNTAJE                  3855 non-null   int64
#  4   RESULT_DESEMPENO                3855 non-null   int64
#  5   ESTU_AGREGADO                   3855 non-null   object
#  6   ESTU_TIPODOCUMENTO              3855 non-null   object
#  7   ESTU_NACIONALIDAD               3855 non-null   object
#  8   ESTU_GENERO                     3855 non-null   object
#  9   ESTU_FECHANACIMIENTO            3855 non-null   object
#  10  ESTU_EXTERIOR                   3855 non-null   object
#  11  PERIODO                         3855 non-null   int64
# ...

# %%
data_limpia=data.drop(['RESULT_CODIGOPRUEBA','ESTU_AGREGADO','ESTU_FECHANACIMIENTO','ESTU_EXTERIOR','PERIODO','ESTU_ESTUDIANTE','ESTU_DEPTO_RESIDE','ESTU_COD_RESIDE_DEPTO','ESTU_AREARESIDE','ESTU_CODDANE_COLE_TERMINO','ESTU_COD_COLE_MCPIO_TERMINO','ESTU_TITULOOBTENIDOBACHILLER','INST_ORIGEN','ESTU_COD_MCPIO_PRESENTACION','MOD_COMUNI_ESCRITA_PNBC','MOD_COMUNI_ESCRITA_PNAL','MOD_COMUNI_ESCRITA_DESEM','MOD_INGLES_PNBC','MOD_INGLES_PNAL','MOD_INGLES_DESEM','MOD_COMPETEN_CIUDADA_PNAL','MOD_COMPETEN_CIUDADA_DESEM','MOD_LECTURA_CRITICA_PNBC','MOD_LECTURA_CRITICA_PNAL','MOD_LECTURA_CRITICA_DESEM','MOD_RAZONA_CUANTITATIVO_PNBC','MOD_RAZONA_CUANTITATIVO_PNAL','MOD_RAZONA_CUANTITAT_DESEM','ESTU_COD_DEPTO_PRESENTACION','ESTU_DEPTO_PRESENTACION','ESTU_MCPIO_PRESENTACION','ESTU_COD_MCPIO_PRESENTACION'], axis=1)

# %%
data_limpia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3855 entries, 0 to 3854
# Data columns (total 65 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ESTU_CONSECUTIVO                3855 non-null   object
#  1   RESULT_NOMBREPRUEBA             3855 non-null   object
#  2   RESULT_PUNTAJE                  3855 non-null   int64
#  3   RESULT_DESEMPENO                3855 non-null   int64
#  4   ESTU_NACIONALIDAD               3855 non-null   object
#  5   ESTU_GENERO                     3855 non-null   object
#  6   ESTU_PAIS_RESIDE                3855 non-null   object
#  7   ESTU_MCPIO_RESIDE               3855 non-null   object
#  8   ESTU_COD_RESIDE_MCPIO           3855 non-null   int64
#  9   ESTU_COLE_TERMINO               2768 non-null   object
#  10  ESTU_VALORMATRICULAUNIVERSIDAD  3850 non-null   object
#  11  ESTU_PAGOMATRICULABECA          3850 non-null   object
# ...

# %%
print(f'cantidad de datos del dataset original contando todos los posibles duplicados: {data_limpia.shape}')
data_limpia.drop_duplicates(inplace = True)
print(f'cantidad de datos del dataset original cuando ya se reviso si habia datos suplicados:  {data_limpia.shape}')
# Out:
# cantidad de datos del dataset original contando todos los posibles duplicados: (3855, 65)
# cantidad de datos del dataset original cuando ya se reviso si habia datos suplicados:  (3855, 65)

# %%
data_limpia.isnull().sum()
# Out:
# ESTU_CONSECUTIVO              0
# RESULT_NOMBREPRUEBA           0
# RESULT_PUNTAJE                0
# RESULT_DESEMPENO              0
# ESTU_NACIONALIDAD             0
#                            ...
# PERCENTIL_GLOBAL              0
# ESTU_INSE_INDIVIDUAL        131
# ESTU_NSE_INDIVIDUAL         131
# ESTU_NSE_IES                  0
# ESTU_ESTADOINVESTIGACION      0
# Length: 65, dtype: int64

# %%
data_limpia.dropna(subset=['ESTU_NSE_INDIVIDUAL', 'ESTU_INSE_INDIVIDUAL'], inplace=True)

# %%
data_limpia.isnull().sum()
# Out:
# ESTU_CONSECUTIVO            0
# RESULT_NOMBREPRUEBA         0
# RESULT_PUNTAJE              0
# RESULT_DESEMPENO            0
# ESTU_NACIONALIDAD           0
#                            ..
# PERCENTIL_GLOBAL            0
# ESTU_INSE_INDIVIDUAL        0
# ESTU_NSE_INDIVIDUAL         0
# ESTU_NSE_IES                0
# ESTU_ESTADOINVESTIGACION    0
# Length: 65, dtype: int64

# %%
data_limpia
# Out:
#      ESTU_CONSECUTIVO RESULT_NOMBREPRUEBA  RESULT_PUNTAJE  RESULT_DESEMPENO  \
# 0      EK202120243329  ANÁLISIS ECONÓMICO             128                 2
# 1      EK202120227314  ANÁLISIS ECONÓMICO             209                 4
# 2      EK202120088295  ANÁLISIS ECONÓMICO             106                 1
# 3      EK202120120119  ANÁLISIS ECONÓMICO              89                 1
# 4      EK202120248108  ANÁLISIS ECONÓMICO             122                 1
# ...               ...                 ...             ...               ...
# 3850   EK202120232172  ANÁLISIS ECONÓMICO             151                 2
# 3851   EK202120320571  ANÁLISIS ECONÓMICO             162                 3
# 3852   EK202120313923  ANÁLISIS ECONÓMICO               0                 1
# 3853   EK202120281981  ANÁLISIS ECONÓMICO             110                 1
# 3854   EK202120224998  ANÁLISIS ECONÓMICO             115                 1
#
# ...

# %%
data_limpia.columns
# Out:
# Index(['ESTU_CONSECUTIVO', 'RESULT_NOMBREPRUEBA', 'RESULT_PUNTAJE',
#        'RESULT_DESEMPENO', 'ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD',
#        'ESTU_GENERO', 'ESTU_PAIS_RESIDE', 'ESTU_MCPIO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_COLE_TERMINO',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_PAGOMATRICULABECA',
#        'ESTU_PAGOMATRICULACREDITO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'ESTU_COMOCAPACITOEXAMENSB11',
#        'ESTU_TIPODOCUMENTOSB11', 'ESTU_SEMESTRECURSA', 'FAMI_EDUCACIONPADRE',
#        'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_ESTRATOVIVIENDA',
#        'ESTU_OTROCOLE_TERMINO', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEHORNOMICROOGAS',
#        'FAMI_TIENESERVICIOTV', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENEMOTOCICLETA',
#        'FAMI_TIENECONSOLAVIDEOJUEGOS', 'FAMI_CUANTOSCOMPARTEBAÑO',
# ...

# %%
g1=sns.countplot(x='ESTU_TIPODOCUMENTO', data=data_limpia)	
plt.title('Grafico de barras con el tipo de documento ')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Tipo de documento del estudiante al momento de presentar la prueba')
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='ESTU_NACIONALIDAD', data=data_limpia)	
plt.title('Grafico de barras por nacionalidad ')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Nacionalidad del estudiante al momento de presentar la prueba')
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='ESTU_GENERO', data=data_limpia)	
plt.title('Grafico de barras por genero ')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Genero del estudiante al momento de presentar la prueba')
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='MOD_COMPETEN_CIUDADA_PUNT', data=data_limpia)	
plt.title('Grafico de barras por puntaje obtenido en lectuta critica ')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='MOD_COMUNI_ESCRITA_PUNT', data=data_limpia)	
plt.title('Grafico de barras por puntaje obtenido en comunicacion escrita ')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='PUNT_GLOBAL', data=data_limpia)	
plt.title('Grafico de barras por puntaje total obtenido en el global ')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='MOD_INGLES_PUNT', data=data_limpia)	
plt.title('Grafico de barras por puntaje obtenido en ingles')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='MOD_COMPETEN_CIUDADA_PUNT', data=data_limpia)	
plt.title('Grafico de barras por puntaje obtenido en competencias ciudadanas')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='FAMI_ESTRATOVIVIENDA', data=data_limpia)	
plt.title('Grafico de barras por estratos socioeconomico')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Estrato')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='ESTU_PAGOMATRICULABECA', data=data_limpia)	
plt.title('Grafico de barras por estudiante si pago la matricula con beca')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Estrato')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='FAMI_EDUCACIONMADRE', data=data_limpia)	
plt.title('Grafico de barras por educacion de la madre')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Estrato')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='FAMI_EDUCACIONPADRE', data=data_limpia)	
plt.title('Grafico de barras por educacion de la madre')
plt.rcParams["figure.figsize"] = (14, 7)
g1.set_xlabel('Estrato')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='ESTU_TIPODOCUMENTO',hue='ESTU_GENERO', data=data_limpia)	
plt.title('Grafico de barras ppor tipo de documento y por genero]')
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Tipo de documento')
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='PUNT_GLOBAL',hue='ESTU_GENERO', data=data_limpia)	
plt.title('Grafico de barras por puntaje global por genero')
sns.set(rc = {'figure.figsize':(13,6)})
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='MOD_INGLES_PUNT',hue='ESTU_GENERO', data=data_limpia)	
plt.title('Grafico de barras por puntaje en la prueba de ingles por genero')
sns.set(rc = {'figure.figsize':(13,6)})
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='MOD_COMPETEN_CIUDADA_PUNT',hue='ESTU_GENERO', data=data_limpia)	
plt.title('Grafico de barras por puntaje en la prueba de competencia ciduadana por genero')
sns.set(rc = {'figure.figsize':(13,6)})
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='MOD_LECTURA_CRITICA_PUNT',hue='ESTU_GENERO', data=data_limpia)	
plt.title('Grafico de barras por puntaje en la prueba de lectura critica por genero')
sns.set(rc = {'figure.figsize':(13,6)})
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.countplot(x='MOD_RAZONA_CUANTITAT_PUNT',hue='ESTU_GENERO', data=data_limpia)	
plt.title('Grafico de barras por puntaje en la prueba de razonamiento cuantitativo por genero')
sns.set(rc = {'figure.figsize':(13,6)})
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.histplot(x='PUNT_GLOBAL',hue='FAMI_ESTRATOVIVIENDA', data=data_limpia)	
plt.title('Grafico de barras por puntaje global por estrato socioeconomico')
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)

plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.histplot(x='PUNT_GLOBAL',hue='FAMI_EDUCACIONPADRE', data=data_limpia)	
plt.title('Grafico de barras por puntaje global por educacion del padre')
#sns.set(rc = {'figure.figsize':(13,6)})
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.histplot(x='PUNT_GLOBAL',hue='FAMI_EDUCACIONMADRE', data=data_limpia)	
plt.title('Grafico de barras por puntaje global por educacion de la madre')
#sns.set(rc = {'figure.figsize':(13,6)})
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.histplot(x='PUNT_GLOBAL',hue='FAMI_TIENEINTERNET', data=data_limpia)	
plt.title('Grafico de barras por puntaje global por si la familia tiene internet en el hogar')
#sns.set(rc = {'figure.figsize':(13,6)})
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
g1=sns.histplot(x='PUNT_GLOBAL',hue='FAMI_ESTRATOVIVIENDA', data=data_limpia)	
plt.title('Grafico de barras por puntaje global por estrato socioeconomico')
#sns.set(rc = {'figure.figsize':(13,6)})
plt.rcParams["figure.figsize"] = (19, 13)
g1.set_xlabel('Puntaje')
plt.xticks(rotation=90)
plt.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
fig, ax=plt.subplots( figsize=(13,4))
graf2=sns.boxplot(data=data, x='PUNT_GLOBAL',palette='Set2').set_title('Sin ajuste')
fig.suptitle('Graficas de bigotes para puntaje global', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Graficas de bigotes para puntaje global')

# %%
fig, ax=plt.subplots( figsize=(13,4))
graf2=sns.boxplot(data=data, x='MOD_INGLES_PUNT',palette='Set2').set_title('Sin ajuste')
fig.suptitle('Graficas de bigotes para puntaje de ingles', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Graficas de bigotes para puntaje de ingles')

# %%
fig, ax=plt.subplots( figsize=(13,4))
graf2=sns.boxplot(data=data, x='MOD_COMPETEN_CIUDADA_PUNT',palette='Set2').set_title('Sin ajuste')
fig.suptitle('Graficas de bigotes para puntaje de competencias ciudadanas', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Graficas de bigotes para puntaje de competencias ciudadanas')

# %%
fig, ax=plt.subplots( figsize=(13,4))
graf2=sns.boxplot(data=data, x='MOD_RAZONA_CUANTITAT_PUNT',palette='Set2').set_title('Sin ajuste')
fig.suptitle('Graficas de bigotes para puntaje de razonamiento cuantitativo', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Graficas de bigotes para puntaje de razonamiento cuantitativo')

# %%
fig, ax=plt.subplots( figsize=(13,4))
graf2=sns.boxplot(data=data, x='MOD_COMUNI_ESCRITA_PUNT',palette='Set2').set_title('Sin ajuste')
fig.suptitle('Graficas de bigotes para puntaje de comunicacion escrita', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Graficas de bigotes para puntaje de comunicacion escrita')

# %%
   data_limpia.columns
# Out:
# Index(['ESTU_CONSECUTIVO', 'RESULT_NOMBREPRUEBA', 'RESULT_PUNTAJE',
#        'RESULT_DESEMPENO', 'ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD',
#        'ESTU_GENERO', 'ESTU_PAIS_RESIDE', 'ESTU_MCPIO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'ESTU_COLE_TERMINO',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_PAGOMATRICULABECA',
#        'ESTU_PAGOMATRICULACREDITO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'ESTU_COMOCAPACITOEXAMENSB11',
#        'ESTU_TIPODOCUMENTOSB11', 'ESTU_SEMESTRECURSA', 'FAMI_EDUCACIONPADRE',
#        'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_ESTRATOVIVIENDA',
#        'ESTU_OTROCOLE_TERMINO', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEHORNOMICROOGAS',
#        'FAMI_TIENESERVICIOTV', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENEMOTOCICLETA',
#        'FAMI_TIENECONSOLAVIDEOJUEGOS', 'FAMI_CUANTOSCOMPARTEBAÑO',
# ...
